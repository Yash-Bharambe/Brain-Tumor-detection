# %% [markdown]
# <a href="https://colab.research.google.com/github/ParasChinchalkar/Brain_Tumor_detection_usingML-/blob/main/tensor_demo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
import numpy as np

# %%
df=pd.read_csv('/content/placement.csv')

# %%
df.head()
# Out:
#    Unnamed: 0  cgpa     iq  placement
# 0           0   6.8  123.0          1
# 1           1   5.9  106.0          0
# 2           2   5.3  121.0          0
# 3           3   7.4  132.0          1
# 4           4   5.8  142.0          0

# %%
df.shape
# Out:
# (100, 4)

# %% [markdown]
# 1)preprocessing+eda+feature selection

# %%
df=df.iloc[:,1:]

# %%
df.head
# Out:
# <bound method NDFrame.head of     cgpa     iq  placement
# 0    6.8  123.0          1
# 1    5.9  106.0          0
# 2    5.3  121.0          0
# 3    7.4  132.0          1
# 4    5.8  142.0          0
# ..   ...    ...        ...
# 95   4.3  200.0          0
# 96   4.4   42.0          0
# 97   6.7  182.0          1
# 98   6.3  103.0          1
# 99   6.2  113.0          1
#
# [100 rows x 3 columns]>

# %%
df.head()
# Out:
#    cgpa     iq  placement
# 0   6.8  123.0          1
# 1   5.9  106.0          0
# 2   5.3  121.0          0
# 3   7.4  132.0          1
# 4   5.8  142.0          0

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(df['cgpa'],df['iq'])

# %%
plt.scatter(df['cgpa'],df['iq'],c=df['placement'])

# %% [markdown]
# extracting input and output coloumns

# %%
x=df.iloc[:,0:2]
y=df.iloc[:,-1]

# %%
df.head
# Out:
# <bound method NDFrame.head of     cgpa     iq  placement
# 0    6.8  123.0          1
# 1    5.9  106.0          0
# 2    5.3  121.0          0
# 3    7.4  132.0          1
# 4    5.8  142.0          0
# ..   ...    ...        ...
# 95   4.3  200.0          0
# 96   4.4   42.0          0
# 97   6.7  182.0          1
# 98   6.3  103.0          1
# 99   6.2  113.0          1
#
# [100 rows x 3 columns]>

# %%
df.head()
# Out:
#    cgpa     iq  placement
# 0   6.8  123.0          1
# 1   5.9  106.0          0
# 2   5.3  121.0          0
# 3   7.4  132.0          1
# 4   5.8  142.0          0

# %%
x
# Out:
#     cgpa     iq
# 0    6.8  123.0
# 1    5.9  106.0
# 2    5.3  121.0
# 3    7.4  132.0
# 4    5.8  142.0
# ..   ...    ...
# 95   4.3  200.0
# 96   4.4   42.0
# 97   6.7  182.0
# 98   6.3  103.0
# 99   6.2  113.0
#
# [100 rows x 2 columns]

# %%
y
# Out:
# 0     1
# 1     0
# 2     0
# 3     1
# 4     0
#      ..
# 95    0
# 96    0
# 97    1
# 98    1
# 99    1
# Name: placement, Length: 100, dtype: int64

# %%
y.shape
# Out:
# (100,)

# %%
x.shape
# Out:
# (100, 2)

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.1)

# %%
# that means that 10percent data ka hi test honga baaki 90 training main jayege

# %%
x_train
# Out:
#     cgpa     iq
# 97   6.7  182.0
# 24   4.7  121.0
# 52   7.0  175.0
# 37   8.1  149.0
# 29   7.0  112.0
# ..   ...    ...
# 16   5.2  224.0
# 56   6.1   65.0
# 70   6.3  127.0
# 63   6.3  128.0
# 43   6.8  141.0
#
# [90 rows x 2 columns]

# %%
y_train
# Out:
# 97    1
# 24    0
# 52    1
# 37    1
# 29    1
#      ..
# 16    0
# 56    0
# 70    1
# 63    1
# 43    1
# Name: placement, Length: 90, dtype: int64

# %%
x_test
# Out:
#     cgpa     iq
# 79   6.5   90.0
# 5    7.1   48.0
# 34   4.8  163.0
# 77   7.3   50.0
# 75   4.8  169.0
# 92   5.2  110.0
# 95   4.3  200.0
# 99   6.2  113.0
# 53   8.3  168.0
# 89   4.9  151.0

# %%
# //sklearn se again preprocessing karenge

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler=StandardScaler()

# %%
x_train=scaler.fit_transform(x_train)

# %%
x_train
# Out:
# array([[ 0.62660953,  1.52601676],
#        [-1.15521851, -0.0594927 ],
#        [ 0.89388373,  1.34407305],
#        [ 1.87388915,  0.66828213],
#        [ 0.89388373, -0.29342033],
#        [ 0.89388373, -1.54103433],
#        [-0.97703571,  0.27840275],
#        [ 1.42843214, -0.89123537],
#        [-1.86794972, -0.37139621],
#        [ 0.09206112, -0.52734796],
#        [ 0.89388373,  0.40836255],
#        [ 1.33934074,  0.17443492],
#        [ 1.16115794,  0.35637863],
#        [-1.06612711, -0.29342033],
#        [-0.7988529 , -1.48905042],
#        [ 0.35933532,  0.46034646],
#        [-0.8879443 , -0.13746858],
#        [ 0.98297513,  0.72026605],
#        [-0.97703571, -0.08548466],
#        [ 0.80479233,  0.40836255],
#        [ 0.09206112, -1.09917104],
#        [ 1.42843214,  0.122451  ],
#        [ 0.62660953,  0.79824192],
#        [ 0.00296971, -1.48905042],
#        [ 1.33934074,  0.90220976],
#        [-2.22431533,  2.85160664],
#        [-0.7097615 ,  0.22641884],
# ...

# %%
x_test=scaler.transform(x_test)

# %%
#Model training honga ab yaha se

# %%
from sklearn.linear_model import LogisticRegression

# %%
clf=LogisticRegression()

# %%
#model training
clf.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
#evaluation main directly accuracy nikalenge on test model
y_predict=clf.predict(x_test)

# %%
x_test
# Out:
# array([[ 0.44842672, -0.86524342],
#        [ 0.98297513, -1.95690567],
#        [-1.06612711,  1.03216955],
#        [ 1.16115794, -1.90492175],
#        [-1.06612711,  1.1881213 ],
#        [-0.7097615 , -0.34540425],
#        [-1.51158412,  1.99387201],
#        [ 0.18115252, -0.26742837],
#        [ 2.05207195,  1.16212934],
#        [-0.97703571,  0.72026605]])

# %%
y_test
# Out:
# 79    1
# 5     1
# 34    0
# 77    1
# 75    0
# 92    0
# 95    0
# 99    1
# 53    1
# 89    0
# Name: placement, dtype: int64

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(y_test,y_predict)
# Out:
# 1.0

# %%
from mlxtend.plotting import plot_decision_regions

# %%
plot_decision_regions(x_train, y_train.values, clf=clf, legend=2)
# Out:
# <Axes: >

# %%
import pickle

# %%
pickle.dump(clf,open('model.pkl','wb'))
